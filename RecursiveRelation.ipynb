# %%
#7$ Find the val%e of T(2) for the rec%rrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

1.Recurrence Relation is T(n) = 3T(n-1) + 12n,

So if n=1,T(1)=3*5+12*1 =27 ,T(0)=5 is given in question

2.Recurrence Relation is T(n) = 3T(n-1) + 12n,

So if n=2,T(2)=3*27+12*2=105

# %%
#2.Given a rec%rrence relation, solve it %sing the s%bstit%tion method:
#a. T(n) = T(n-1) + c
#b. T(n) = 2T(n/2) + n
#c. T(n) = 2T(n/2) + c
#d. T(n) = T(n/2) + c

(a)

Let's say that your base case is T(1) = b, 

T(2) = T(1) + c = b + c

T(3) = T(2) + c = b + c + c



T(4) = T(3) + c = b + c + c + c

T(5) = T(4) + c = b + c + c + c + c

So now the pattern becomes clear:

T(n) = b + (n-1)c for n >= 2, and the base case of T(1) = b


(b)


T(n)=2T(n/2) + n



T(n/2)=2T(n/4)+n/2

T(N/4)=2T(n/8)+n/4

T(n/2)=2T(n/4)+n/2

      =2[T(n/4)+n/2]+n
      =2**3T(n/2**3)+ 3n
      =

Next will be : =2**4T(n/2**4)+ 4n

Generalise: 2**kT(n/2**k)+ kn

Sunstitute n/(2**k)=1

n+nlogn


c. T(n) = 2T(n/2) + c

T(n)=2T(n/2)+c
     =2{2T(n/4)+c)+c
     =4T(n/4)+3c
     =n.T(1)+(n-1)c
     =n.c+(n-1)c
     =2nc-c
     =O(n).
# Out:
#   Cell In[1], line 9
#     Let's say that your base case is T(1) = b,
#        ^
# SyntaxError: unterminated string literal (detected at line 9)

# %%
#3 Recursive Tree approach

(a)T(n) = 2T(n-1) +1

Link for Tree :  https://i.stack.imgur.com/APf8B.png

Work per Level= 2^n

T(n)== θ(2^n)


b. T(n) = 2T(n/2) + n

In this problem, one can observe that the problem is getting split into two problems of half the initial size. Further the additional cost here equals the size. Hence, after the first division, the recursion tree will have two child nodes with input size n/2. We then proceed in this manner until the final input size becomes 1. Therefore, the final recursion tree will look as follows (note that each node contains only the extra cost that is taken) :
    
   
For Tree Pl refer -  https://iq.opengenus.org/content/images/2022/01/recursex1.png

As the recursion tree is complete, it remains to calculate the total sum of the entries. For that, we first need to determine the number of levels in the recursion tree. Since each level of the tree splits each of the nodes in that level to half the size of their parents, one can conclude that the total number of levels here is log2n.

The next thing we note here is that in each level, the sum of the nodes is n. Therefore, the overall time complexity is given by:

T(n) = n + n + .... log2n times
= n ( 1 + 1 + ....log2n times)
= n log2n
= θ(n log2n)
